# %%
import danrerlib as drl
import pandas as pd
from danrerlib import KEGG, enrichment, mapping
from pandas.testing import assert_frame_equal
from danrerlib.settings import *
import json

# %%
gene_universe_path = 'data/in_data/01_TPP.txt'
# gene_universe_path = 'data/in_data/example_diff_express_data.txt'
gene_universe = pd.read_csv(gene_universe_path, sep = '\t')

enrichment.enrich(gene_universe, 
                  'NCBI Gene ID', 
                  'KEGG Pathway', 
                  'dre', 
                  'fishers',
                  'down')
# Out:
#     Concept Type Concept ID                                 Concept Name  \
# 0   KEGG Pathway   dre01200                            Carbon metabolism
# 1   KEGG Pathway   dre03013                  Nucleocytoplasmic transport
# 2   KEGG Pathway   dre04512                     ECM-receptor interaction
# 3   KEGG Pathway   dre04141  Protein processing in endoplasmic reticulum
# 4   KEGG Pathway   dre00030                    Pentose phosphate pathway
# 5   KEGG Pathway   dre04340                   Hedgehog signaling pathway
# 6   KEGG Pathway   dre04060       Cytokine-cytokine receptor interaction
# 7   KEGG Pathway   dre04510                               Focal adhesion
# 8   KEGG Pathway   dre04110                                   Cell cycle
# 9   KEGG Pathway   dre00970                  Aminoacyl-tRNA biosynthesis
# 10  KEGG Pathway   dre00071                       Fatty acid degradation
# 11  KEGG Pathway   dre03030                              DNA replication
# 12  KEGG Pathway   dre00670                    One carbon pool by folate
# 13  KEGG Pathway   dre00010                 Glycolysis / Gluconeogenesis
# 14  KEGG Pathway   dre00020                    Citrate cycle (TCA cycle)
# 15  KEGG Pathway   dre03410                         Base excision repair
# 16  KEGG Pathway   dre03082           ATP-dependent chromatin remodeling
# 17  KEGG Pathway   dre00051              Fructose and mannose metabolism
# 18  KEGG Pathway   dre04080      Neuroactive ligand-receptor interaction
# 19  KEGG Pathway   dre04916                                Melanogenesis
# 20  KEGG Pathway   dre01100                           Metabolic pathways
# 21  KEGG Pathway   dre00785                       Lipoic acid metabolism
# 22  KEGG Pathway   dre00640                        Propanoate metabolism
# 23  KEGG Pathway   dre03008            Ribosome biogenesis in eukaryotes
# 24  KEGG Pathway   dre04914      Progesterone-mediated oocyte maturation
# 25  KEGG Pathway   dre01230                  Biosynthesis of amino acids
# 26  KEGG Pathway   dre04310                        Wnt signaling pathway
# 27  KEGG Pathway   dre03040                                  Spliceosome
# 28  KEGG Pathway   dre04216                                  Ferroptosis
# 29  KEGG Pathway   dre03018                              RNA degradation
# 30  KEGG Pathway   dre01250            Biosynthesis of nucleotide sugars
# 31  KEGG Pathway   dre04540                                 Gap junction
# 32  KEGG Pathway   dre04114                               Oocyte meiosis
# 33  KEGG Pathway   dre04371                     Apelin signaling pathway
# 34  KEGG Pathway   dre00630      Glyoxylate and dicarboxylate metabolism
# 35  KEGG Pathway   dre03320                       PPAR signaling pathway
# 36  KEGG Pathway   dre00061                      Fatty acid biosynthesis
#
#     # Genes in Concept in Universe  # Sig Genes Belong to Concept  \
# 0                              124                             30
# 1                              100                             26
# 2                              101                             24
# 3                              190                             34
# 4                               29                             10
# 5                               68                             16
# 6                              153                              2
# 7                              264                             41
# 8                              177                             29
# 9                               51                             12
# 10                              54                             12
# 11                              35                              9
# 12                              19                              6
# 13                              75                             14
# 14                              33                              8
# 15                              47                             10
# 16                             108                             18
# 17                              42                              9
# 18                             417                             22
# 19                             131                             20
# 20                            1648                            172
# 21                              17                              5
# 22                              30                              7
# 23                              68                             12
# 24                             100                             16
# 25                              85                             14
# 26                             214                             29
# 27                             135                             20
# 28                              54                             10
# 29                              79                             13
# 30                              42                              8
# 31                             115                             17
# 32                             134                             19
# 33                             177                             24
# 34                              36                              7
# 35                              89                             14
# 36                              22                              5
#
#     Proportion of Sig Genes in Set  Odds Ratio       P-value Direction
# 0                         0.241935    3.377603  2.046269e-07  enriched
# 1                         0.260000    3.714232  2.888148e-07  enriched
# 2                         0.237624    3.290945  4.593542e-06  enriched
# 3                         0.178947    2.304295  4.832602e-05  enriched
# 4                         0.344828    5.532145  1.058268e-04  enriched
# 5                         0.235294    3.239072  1.945726e-04  enriched
# 6                         0.013072    0.137716  2.338975e-04  depleted
# 7                         0.155303    1.944541  2.607694e-04  enriched
# 8                         0.163842    2.066984  1.094084e-03  enriched
# 9                         0.235294    3.234343  1.192580e-03  enriched
# 10                        0.222222    3.002866  2.018885e-03  enriched
# 11                        0.257143    3.635254  2.504128e-03  enriched
# 12                        0.315789    4.842510  4.378043e-03  enriched
# 13                        0.186667    2.412383  6.010547e-03  enriched
# 14                        0.242424    3.358988  6.324257e-03  enriched
# 15                        0.212766    2.838265  6.447336e-03  enriched
# 16                        0.166667    2.103602  8.877088e-03  enriched
# 17                        0.214286    2.863133  9.099629e-03  enriched
# 18                        0.052758    0.578040  1.071418e-02  depleted
# 19                        0.152672    1.895140  1.225971e-02  enriched
# 20                        0.104369    1.241386  1.243712e-02  enriched
# 21                        0.294118    4.369630  1.274518e-02  enriched
# 22                        0.233333    3.193328  1.291336e-02  enriched
# 23                        0.176471    2.250566  1.584212e-02  enriched
# 24                        0.160000    2.001915  1.864761e-02  enriched
# 25                        0.164706    2.071569  1.875093e-02  enriched
# 26                        0.135514    1.650497  1.968530e-02  enriched
# 27                        0.148148    1.828853  2.008244e-02  enriched
# 28                        0.185185    2.385884  2.431225e-02  enriched
# 29                        0.164557    2.068754  2.492185e-02  enriched
# 30                        0.190476    2.468729  2.679123e-02  enriched
# 31                        0.147826    1.822852  2.952151e-02  enriched
# 32                        0.141791    1.736490  3.095138e-02  enriched
# 33                        0.135593    1.649893  3.096984e-02  enriched
# 34                        0.194444    2.531877  3.357706e-02  enriched
# 35                        0.157303    1.960691  3.495996e-02  enriched
# 36                        0.227273    3.083671  3.772637e-02  enriched

# %%
gene_universe_data = {
    'GeneID': ['Gene1', 'Gene2', 'Gene3', 'Gene4', 'Gene 5'],
    'PValue': [0.01, 0.05, 0.001, 0.1, 0.04],
    'logFC': [0.5, -0.8, 1.2, -0.3, -0.1]
}

gene_universe = pd.DataFrame(gene_universe_data)


sig_genes_set = enrichment._get_sig_genes_set(gene_universe, 'both', 'GeneID', 0.05, 0.0)
sig_genes_set
# Out:
# {'Gene 5', 'Gene1', 'Gene3'}

# %%
file_path1 = 'data/out_data/enrich/fishers1.txt'
with open(file_path1, 'r') as file:
    true_dictionary = json.load(file)

# %%
gene_universe = pd.read_csv('data/in_data/example_diff_express_data.txt', sep = '\t')
kegg_pathway = pd.read_csv('data/in_data/enrich/dre04340.txt', sep = '\t')
enrichment.fishers(gene_universe, kegg_pathway, 
                    'NCBI Gene ID', 
                    'KEGG Pathway', 
                    'dre04340',
                    'WNT Signaling Pathway')
# Out:
# {'Concept Type': 'KEGG Pathway',
#  'Concept ID': 'dre04340',
#  'Concept Name': 'WNT Signaling Pathway',
#  '# Genes in Concept in Universe': 15,
#  '# Sig Genes Belong to Concept': 4,
#  'Proportion of Sig Genes in Set': 0.26666666666666666,
#  'Odds Ratio': 1.5943226733740568,
#  'P-value': 0.29958958403571007,
#  'Direction': 'enriched'}

# %%
gene_universe
# Out:
#        NCBI Gene ID        PValue     logFC
# 0         100000006  7.926150e-01  0.115009
# 1         100000009  6.072851e-01 -0.144714
# 2         100000026  2.133828e-02  0.603871
# 3         100000030  7.879818e-03 -2.083141
# 4         100000044  1.528565e-02  0.803879
# ...             ...           ...       ...
# 21849         84039  6.414131e-01 -0.079046
# 21850         84040  4.641648e-02 -0.354699
# 21851         84041  2.616808e-02  2.302526
# 21852         84702  8.650000e-10 -1.310207
# 21853         84703  9.947610e-01 -0.002397
#
# [21854 rows x 3 columns]

# %%
# gene_universe_path = 'data/in_data/01_TPP.txt'
# gene_universe = pd.read_csv(gene_universe_path, sep = '\t')
# gene_universe = mapping.add_mapped_ortholog_column(gene_universe, 'NCBI Gene ID', "Human NCBI Gene ID", keep_old_ids=False, drop_na=True)
enrichment.enrich(gene_universe, 'NCBI Gene ID', 'KEGG Pathway', 'dre', 'fishers')
# Out:
#     Concept Type Concept ID                                 Concept Name  \
# 0   KEGG Pathway   dre00030                    Pentose phosphate pathway
# 1   KEGG Pathway   dre04512                     ECM-receptor interaction
# 2   KEGG Pathway   dre04141  Protein processing in endoplasmic reticulum
# 3   KEGG Pathway   dre04010                       MAPK signaling pathway
# 4   KEGG Pathway   dre04510                               Focal adhesion
# 5   KEGG Pathway   dre04340                   Hedgehog signaling pathway
# 6   KEGG Pathway   dre01200                            Carbon metabolism
# 7   KEGG Pathway   dre04914      Progesterone-mediated oocyte maturation
# 8   KEGG Pathway   dre03013                  Nucleocytoplasmic transport
# 9   KEGG Pathway   dre04068                       FoxO signaling pathway
# 10  KEGG Pathway   dre04520                            Adherens junction
# 11  KEGG Pathway   dre04070        Phosphatidylinositol signaling system
# 12  KEGG Pathway   dre04144                                  Endocytosis
# 13  KEGG Pathway   dre04920              Adipocytokine signaling pathway
# 14  KEGG Pathway   dre04371                     Apelin signaling pathway
# 15  KEGG Pathway   dre03410                         Base excision repair
# 16  KEGG Pathway   dre04012                       ErbB signaling pathway
# 17  KEGG Pathway   dre04140                           Autophagy - animal
# 18  KEGG Pathway   dre04150                       mTOR signaling pathway
# 19  KEGG Pathway   dre03018                              RNA degradation
# 20  KEGG Pathway   dre00310                           Lysine degradation
# 21  KEGG Pathway   dre04216                                  Ferroptosis
# 22  KEGG Pathway   dre00071                       Fatty acid degradation
# 23  KEGG Pathway   dre04370                       VEGF signaling pathway
# 24  KEGG Pathway   dre03030                              DNA replication
# 25  KEGG Pathway   dre00670                    One carbon pool by folate
# 26  KEGG Pathway   dre04130    SNARE interactions in vesicular transport
#
#     # Genes in Concept in Universe  # Sig Genes Belong to Concept  \
# 0                               29                             15
# 1                              101                             35
# 2                              190                             54
# 3                              377                             95
# 4                              264                             69
# 5                               68                             23
# 6                              124                             36
# 7                              100                             29
# 8                              100                             29
# 9                              160                             42
# 10                             142                             38
# 11                             117                             32
# 12                             325                             76
# 13                              89                             25
# 14                             177                             44
# 15                              47                             15
# 16                             104                             28
# 17                             180                             44
# 18                             180                             44
# 19                              79                             22
# 20                              80                             22
# 21                              54                             16
# 22                              54                             16
# 23                              76                             21
# 24                              35                             11
# 25                              19                              7
# 26                              40                             12
#
#     Proportion of Sig Genes in Set  Odds Ratio   P-value Direction
# 0                         0.517241    4.872631  0.000041  enriched
# 1                         0.346535    2.416984  0.000051  enriched
# 2                         0.284211    1.811383  0.000292  enriched
# 3                         0.251989    1.540432  0.000308  enriched
# 4                         0.261364    1.615107  0.000674  enriched
# 5                         0.338235    2.325126  0.001356  enriched
# 6                         0.290323    1.862707  0.001847  enriched
# 7                         0.290000    1.858242  0.004938  enriched
# 8                         0.290000    1.858242  0.004938  enriched
# 9                         0.262500    1.620416  0.006320  enriched
# 10                        0.267606    1.663056  0.006497  enriched
# 11                        0.273504    1.712715  0.008451  enriched
# 12                        0.233846    1.391423  0.008859  enriched
# 13                        0.280899    1.776030  0.013131  enriched
# 14                        0.248588    1.505623  0.014347  enriched
# 15                        0.319149    2.129631  0.015562  enriched
# 16                        0.269231    1.675231  0.016243  enriched
# 17                        0.244444    1.472162  0.019085  enriched
# 18                        0.244444    1.472162  0.019085  enriched
# 19                        0.278481    1.754189  0.021121  enriched
# 20                        0.275000    1.723848  0.024299  enriched
# 21                        0.296296    1.912776  0.025967  enriched
# 22                        0.296296    1.912776  0.025967  enriched
# 23                        0.276316    1.735095  0.025970  enriched
# 24                        0.314286    2.081122  0.039636  enriched
# 25                        0.368421    2.647789  0.041795  enriched
# 26                        0.300000    1.946043  0.045606  enriched

# %%
p = KEGG.get_genes_in_pathway('dre04340')
p
# Out:
#     NCBI Gene ID
# 0      100001615
# 1      100005514
# 2      100006858
# 3      100007048
# 4      100332121
# ..           ...
# 64        791154
# 65        792224
# 66        793939
# 67        796318
# 68        799608
#
# [69 rows x 1 columns]

# %%
p.to_csv('../tests/data/in_data/dre04340.txt', sep = '\t', index = False)

# %%
gene_universe
# Out:
#       Human NCBI Gene ID        PValue     logFC
# 0                  84561  7.926150e-01  0.115009
# 1                  54437  6.072851e-01 -0.144714
# 2                    218  2.133828e-02  0.603871
# 5                   9480  4.635741e-03  2.158962
# 8                    968  2.647625e-01  0.267360
# ...                  ...           ...       ...
# 21897              57045  5.418643e-01  0.116959
# 21898              53630  6.414131e-01 -0.079046
# 21899               9022  4.641648e-02 -0.354699
# 21901               1356  8.650000e-10 -1.310207
# 21902               6521  9.947610e-01 -0.002397
#
# [14144 rows x 3 columns]

# %%
enrichment.enrich(gene_universe, 'NCBI Gene ID', 'KEGG Pathway', 'dre', 'fishers', concept_ids=['dre04110', 'dre04310'])
# Out:
#    Concept Type Concept ID           Concept Name  \
# 0  KEGG Pathway   dre04310  Wnt signaling pathway
# 1  KEGG Pathway   dre04110             Cell cycle
#
#    # Genes in Concept in Universe  # Sig Genes Belong to Concept  \
# 0                             214                             47
# 1                             177                             37
#
#    Proportion of Sig Genes in Set  Odds Ratio   P-value Direction
# 0                        0.219626    1.279378  0.083420  enriched
# 1                        0.209040    1.200163  0.186579  enriched

# %%
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# /Users/ashleyschwartz/Documents/Research/06_multilayer_network/Perliminary/danrerlib/tests/sctratch.ipynb Cell 4 line 1
# ----> <a href='vscode-notebook-cell:/Users/ashleyschwartz/Documents/Research/06_multilayer_network/Perliminary/danrerlib/tests/sctratch.ipynb#W2sZmlsZQ%3D%3D?line=0'>1</a> enrichment.enrich(gene_universe, 'NCBI Gene ID', 'KEGG Disease', 'dre', 'fishers')
#
# File ~/Documents/Research/06_multilayer_network/Perliminary/danrerlib/src/danrerlib/enrichment.py:428, in enrich(gene_universe, gene_id_type, database, org, method, sig_gene_cutoff_pvalue, concept_ids, sig_conceptID_cutoff_pvalue, order_by_p_value, include_all)
#     425 resulting_dictionary_list = []
#     426 for concept_id in concept_ids:
# --> 428     gene_set =  get_genes_function(concept_id, org, do_check = False)
#     429     # if type(gene_set) != pd.DataFrame:
#     430     #     gene_set = pd.DataFrame(gene_set)
#     431     concept_name = all_ids.loc[all_ids[id_column_name] == concept_id, name_column_name].values[0]
#
# TypeError: get_genes_in_disease() got an unexpected keyword argument 'do_check'

# %%
KEGG.get_genes_in_disease('H00001', 'hsa')
# Out:
#    Human NCBI Gene ID
# 0                  25
# 1                4297
# 2                4299
# 3                6929
# 4                5087
# 5                 861
# 6                4609
# 7               64109
# 8                5079

# %%
disease_id = 'H00001'
file_name = 'data/out_data/kegg/'+disease_id+'.txt'
true_gene_ids = pd.read_csv(file_name, sep = '\t')
true_gene_ids
# Out:
#    Human NCBI Gene ID
# 0                  25
# 1                4297
# 2                4299
# 3                6929
# 4                5087
# 5                 861
# 6                4609
# 7               64109
# 8                5079

# %%
generated_gene_ids = KEGG.get_genes_in_disease(disease_id, 'hsa')
generated_gene_ids
# Out:
#    Human NCBI Gene ID
# 0                  25
# 1                4297
# 2                4299
# 3                6929
# 4                5087
# 5                 861
# 6                4609
# 7               64109
# 8                5079

# %%
assert_frame_equal(true_gene_ids, generated_gene_ids)

# %%
file_name = 'data/out_data/kegg/'+disease_id+'_dre.txt'
true_gene_ids = pd.read_csv(file_name, sep = '\t').sort_values(by = NCBI_ID).reset_index(drop = True)
true_gene_ids
# Out:
#     NCBI Gene ID
# 0          30310
# 1          30686
# 2          58126
# 3          58138
# 4          60636
# 5         393141
# 6         557048
# 7         570960
# 8         664768
# 9      100000720
# 10     100294510
# 11     100537394

# %%
generated_gene_ids = KEGG.get_genes_in_disease(disease_id, 'dre').sort_values(by = NCBI_ID).reset_index(drop = True)
generated_gene_ids
# Out:
#     NCBI Gene ID
# 0          30310
# 1          30686
# 2          58126
# 3          58138
# 4          60636
# 5         393141
# 6         557048
# 7         570960
# 8         664768
# 9      100000720
# 10     100294510
# 11     100537394

# %%
generated_gene_ids.iloc[0]
# Out:
# NCBI Gene ID    30310
# Name: 0, dtype: int64

# %%
drl.utils.normalize_gene_id_type(' zfi  ')
# Out:
# ' zfi  '

# %%
GO.get_genes_in_GO_concept('GO:0005173', 'dre', 'symbol')
# Out:
# One or more of the zebrafish Gene ID types you gave is invalid. The valid zebrafish
# Gene ID options are: NCBI Gene ID, ZFIN ID, Ensembl ID, and Symbol. The ID(s) you gave
# that are invalid are:
# ----------
# symbol
# ----------
# Reminder: Gene ID types are case and spelling sensitive.

# %%
def test_get_genes_from_go_id():
    go_id = 'GO:0005173'
    org = 'dre'
    generated_genes = GO.get_genes_in_GO_concept(go_id)
    generated_genes = generated_genes.to_frame()

    true_genes = pd.read_csv('data/out_data/go/id_dre_0007063.txt')
    true_genes = true_genes.to_frame
    assert_frame_equal(true_genes, generated_genes)

# %%
go_id = 'GO:0005173'
GO.get_genes_in_GO_concept(go_id, 'hsa')
# Out:
# 0      4254
# 1     10019
# 2    161742
# 3    200734
# Name: Human NCBI Gene ID, dtype: int64

# %%
go_id = 'GO:0005173'
org = 'dre'
generated_genes = GO.get_genes_in_GO_concept(go_id, org, 'Symbol')
generated_genes = generated_genes.to_frame().sort_values(by='Symbol', ascending=True).reset_index(drop=True)
generated_genes
# Out:
#    Symbol
# 0  kitlga
# 1  kitlgb

# %%
true_genes = pd.read_csv('data/out_data/go/id_dre_0007063.txt').sort_values(by='Symbol', ascending=True).reset_index(drop=True)
true_genes
# Out:
#    Symbol
# 0  kitlga
# 1  kitlgb

# %%
assert_frame_equal(generated_genes, true_genes)
